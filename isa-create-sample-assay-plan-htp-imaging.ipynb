# %% [markdown]
# ## ISA Create - Sample Assay Plan as a Graph: Phenotyping by HT imaging Spectrometry
# Here I am showing how from a JSON-like dictionary describing an NMR experiment you can create a full SampleAssayPlan as a graph and visualize how this looks like

# %%
from isaagents.model import *
from isaagents.create.models import *
import networkx as nx
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import pydot
from graphviz import Digraph
import pygraphviz

# %%
# %matplotlib inline

# %%
# from: https://stackoverflow.com/questions/29586520/can-one-get-hierarchical-graphs-from-networkx-with-python-3/29597209
def hierarchy_pos(G, root=None, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5):

    '''
    From Joel's answer at https://stackoverflow.com/a/29597209/2966723.  
    Licensed under Creative Commons Attribution-Share Alike 

    If the graph is a tree this will return the positions to plot this in a 
    hierarchical layout.

    G: the graph (must be a tree)

    root: the root node of current branch 
    - if the tree is directed and this is not given, 
      the root will be found and used
    - if the tree is directed and this is given, then 
      the positions will be just for the descendants of this node.
    - if the tree is undirected and not given, 
      then a random choice will be used.

    width: horizontal space allocated for this branch - avoids overlap with other branches

    vert_gap: gap between levels of hierarchy

    vert_loc: vertical location of root

    xcenter: horizontal location of root
    '''
# NOTE: This was commented out for testing with ISA-API output (a DiGraph)   
#     if not nx.is_tree(G):
#         raise TypeError('cannot use hierarchy_pos on a graph that is not a tree')

    if root is None:
        if isinstance(G, nx.DiGraph):
            root = next(iter(nx.topological_sort(G)))  #allows back compatibility with nx version 1.11
        else:
            root = random.choice(list(G.nodes))

    def _hierarchy_pos(G, root, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5, pos = None, parent = None):
        '''
        see hierarchy_pos docstring for most arguments

        pos: a dict saying where all nodes go if they have been assigned
        parent: parent of this branch. - only affects it if non-directed

        '''

        if pos is None:
            pos = {root:(xcenter,vert_loc)}
        else:
            pos[root] = (xcenter, vert_loc)
        children = list(G.neighbors(root))
        if not isinstance(G, nx.DiGraph) and parent is not None:
            children.remove(parent)  
        if len(children)!=0:
            dx = width/len(children) 
            nextx = xcenter - width/2 - dx/2
            for child in children:
                nextx += dx
                pos = _hierarchy_pos(G,child, width = dx, vert_gap = vert_gap, 
                                    vert_loc = vert_loc-vert_gap, xcenter=nextx,
                                    pos=pos, parent = root)
        return pos


    return _hierarchy_pos(G, root, width, vert_gap, vert_loc, xcenter)

# %% [markdown]
# Here we define the structure of our sampling and assay plan, using a Python dictionary. From it we create a full `isaagents.create.models.SampleAssayPlan` object

# %%
phti_assay_dict = OrderedDict([
            ('sample', [
                {
                    'node_type': SAMPLE,
                    'characteristics_category': 'organism part',
                    'characteristics_value': 'liver',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': SAMPLE,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'supernatant',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                },
                {
                    'node_type': SAMPLE,
                    'characteristics_category': 'extract type',
                    'characteristics_value': 'pellet',
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('phenotyping by high throughput imaging', {
                'instrument': ['lemnatech gigant'],
                'acquisition_mode': ['UV light','near-IR light','far-IR light','visible light'],
                'camera position': ['top','120 degree','240 degree','360 degree'],
                'imaging daily schedule': ['06.00','19.00']
            }),
            ('raw_spectral_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 2,
                    'is_input_to_next_protocols': False
                }
            ])
        ])
phti_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict(phti_assay_dict)
# Out:
# pv_combination: ()
# count: 0, prev_node: sample_000
# count: 0, prev_node: extraction_000_000
# count: 0, prev_node: extraction_000_000
# pv_combination: ('lemnatech gigant', 'UV light', 'top', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', 'top', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '120 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '120 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '240 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '240 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '360 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'UV light', '360 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', 'top', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', 'top', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '120 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '120 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '240 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '240 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '360 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'near-IR light', '360 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', 'top', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', 'top', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '120 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '120 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '240 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '240 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '360 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'far-IR light', '360 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', 'top', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', 'top', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '120 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '120 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '240 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '240 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '360 degree', '06.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# pv_combination: ('lemnatech gigant', 'visible light', '360 degree', '19.00')
# count: 0, prev_node: extract_000_000
# count: 1, prev_node: extract_001_000
# count: 0, prev_node: phenotyping by high throughput imaging_000_000
# count: 1, prev_node: phenotyping by high throughput imaging_000_001
# count: 2, prev_node: phenotyping by high throughput imaging_001_000
# count: 3, prev_node: phenotyping by high throughput imaging_001_001
# count: 4, prev_node: phenotyping by high throughput imaging_002_000
# count: 5, prev_node: phenotyping by high throughput imaging_002_001
# count: 6, prev_node: phenotyping by high throughput imaging_003_000
# count: 7, prev_node: phenotyping by high throughput imaging_003_001
# count: 8, prev_node: phenotyping by high throughput imaging_004_000
# count: 9, prev_node: phenotyping by high throughput imaging_004_001
# count: 10, prev_node: phenotyping by high throughput imaging_005_000
# count: 11, prev_node: phenotyping by high throughput imaging_005_001
# count: 12, prev_node: phenotyping by high throughput imaging_006_000
# count: 13, prev_node: phenotyping by high throughput imaging_006_001
# count: 14, prev_node: phenotyping by high throughput imaging_007_000
# count: 15, prev_node: phenotyping by high throughput imaging_007_001
# count: 16, prev_node: phenotyping by high throughput imaging_008_000
# count: 17, prev_node: phenotyping by high throughput imaging_008_001
# count: 18, prev_node: phenotyping by high throughput imaging_009_000
# count: 19, prev_node: phenotyping by high throughput imaging_009_001
# count: 20, prev_node: phenotyping by high throughput imaging_010_000
# count: 21, prev_node: phenotyping by high throughput imaging_010_001
# count: 22, prev_node: phenotyping by high throughput imaging_011_000
# count: 23, prev_node: phenotyping by high throughput imaging_011_001
# count: 24, prev_node: phenotyping by high throughput imaging_012_000
# count: 25, prev_node: phenotyping by high throughput imaging_012_001
# count: 26, prev_node: phenotyping by high throughput imaging_013_000
# count: 27, prev_node: phenotyping by high throughput imaging_013_001
# count: 28, prev_node: phenotyping by high throughput imaging_014_000
# count: 29, prev_node: phenotyping by high throughput imaging_014_001
# count: 30, prev_node: phenotyping by high throughput imaging_015_000
# count: 31, prev_node: phenotyping by high throughput imaging_015_001
# count: 32, prev_node: phenotyping by high throughput imaging_016_000
# count: 33, prev_node: phenotyping by high throughput imaging_016_001
# count: 34, prev_node: phenotyping by high throughput imaging_017_000
# count: 35, prev_node: phenotyping by high throughput imaging_017_001
# count: 36, prev_node: phenotyping by high throughput imaging_018_000
# count: 37, prev_node: phenotyping by high throughput imaging_018_001
# count: 38, prev_node: phenotyping by high throughput imaging_019_000
# count: 39, prev_node: phenotyping by high throughput imaging_019_001
# count: 40, prev_node: phenotyping by high throughput imaging_020_000
# count: 41, prev_node: phenotyping by high throughput imaging_020_001
# count: 42, prev_node: phenotyping by high throughput imaging_021_000
# count: 43, prev_node: phenotyping by high throughput imaging_021_001
# count: 44, prev_node: phenotyping by high throughput imaging_022_000
# count: 45, prev_node: phenotyping by high throughput imaging_022_001
# count: 46, prev_node: phenotyping by high throughput imaging_023_000
# count: 47, prev_node: phenotyping by high throughput imaging_023_001
# count: 48, prev_node: phenotyping by high throughput imaging_024_000
# count: 49, prev_node: phenotyping by high throughput imaging_024_001
# count: 50, prev_node: phenotyping by high throughput imaging_025_000
# count: 51, prev_node: phenotyping by high throughput imaging_025_001
# count: 52, prev_node: phenotyping by high throughput imaging_026_000
# count: 53, prev_node: phenotyping by high throughput imaging_026_001
# count: 54, prev_node: phenotyping by high throughput imaging_027_000
# count: 55, prev_node: phenotyping by high throughput imaging_027_001
# count: 56, prev_node: phenotyping by high throughput imaging_028_000
# count: 57, prev_node: phenotyping by high throughput imaging_028_001
# count: 58, prev_node: phenotyping by high throughput imaging_029_000
# count: 59, prev_node: phenotyping by high throughput imaging_029_001
# count: 60, prev_node: phenotyping by high throughput imaging_030_000
# count: 61, prev_node: phenotyping by high throughput imaging_030_001
# count: 62, prev_node: phenotyping by high throughput imaging_031_000
# count: 63, prev_node: phenotyping by high throughput imaging_031_001

# %% [markdown]
# The `phti_assay_plan` object is a graph. Let's which are its `nodes`.

# %%
nx_graph = phti_assay_plan.as_networkx_graph()
# set(nx_graph.nodes)
nx_graph.number_of_nodes()
# Out:
# 132

# %% [markdown]
# Here we print the `links` or `edges` of the graph

# %% [raw]
# # set(nx_graph.edges)
# nx_graph.number_of_edges()

# %%
nx_graph.size()
# Out:
# 131

# %% [markdown]
# We output is as a `networkx` graph and we visualize it using `matplotlib`

# %%
G=nx_graph

# %%
# nx.draw(G)

# %%
nx.draw(nx_graph,pos=nx.spring_layout(G),node_color=range(G.number_of_nodes()),cmap=plt.cm.Blues, with_labels=False)

# %%
SG1 = G.subgraph(['sample_000','extraction_000_000','extract_000_000','extract_001_000','labeling_000_000','labeling_000_003','labeled_extract_000_000','labeled_extract_000_003'])
# print(list(SG.edges))
pos1 = hierarchy_pos(SG1,'sample_000')    
nx.draw(SG1, pos=pos1, with_labels=True,node_color = 'b')
plt.savefig('hierarchy1.png')


# SG2 = G.subgraph(['sample_001','extraction_000_001','extract_000_001','extract_001_001','labeling_000_001','labeling_000_004','labeled_extract_000_001','labeled_extract_000_004'])
# # print(list(SG.edges))
# pos2 = hierarchy_pos(SG2,'sample_001')    
# nx.draw(SG2, pos=pos2, with_labels=True,node_color = 'pink')
# plt.savefig('hierarchy2.png')

# %%
# Generating a graphviz compatible output
dot = Digraph()
for node in nx_graph.nodes:
    dot.node(node)
dot.edges(nx_graph.edges)
filename=dot.filename
# print(dot.source)
dot.graph_attr['rankdir'] = 'LR' # to layout from left to right (horizontal), rather than top to bottom (vertical)
dot.render(filename, view=True)
# Out:
# 'Digraph.gv.pdf'

# %%
# nx.draw_networkx_edges(nx_graph,pos=nx.spring_layout(nx_graph))
# fig = go.Figure(data=[nx_graph.nodes,nx_graph.edges])

# %%
# nx.draw(nx_graph, with_labels=False, font_weight='bold')

# %%
nx.drawing.draw_planar(nx_graph,node_color=range(G.number_of_nodes()),cmap=plt.cm.Blues, style='dashed')

# %%
nx.nx_agraph.to_agraph(nx_graph).layout()

# %%
nx.nx_agraph.to_agraph(nx_graph).write("isa-test.dot")

# %%
G=nx.nx_agraph.read_dot("isa-test.dot")

# %%
# G = nx.bipartite.gnmk_random_graph(3, 5, 10, seed=123)
# top = nx.bipartite.sets(G)[3]
# pos = nx.bipartite_layout(G, top)
# pos = nx.planar_layout(G)

# %%
pos=nx.drawing.layout.planar_layout(G, scale=2, center=None, dim=2)

# %%
nx.draw(nx_graph,pos=nx.drawing.layout.planar_layout(G, scale=1, center=None, dim=2),node_color=range(G.number_of_nodes()),cmap=plt.cm.Blues)

# %%
NG = nx.karate_club_graph()
res = [0,1,2,3,4,5, 'parrot'] #I've added 'parrot', a node that's not in G
                              #just to demonstrate that G.subgraph is okay
                              #with nodes not in G.
k = NG.subgraph(res)          
pos = nx.spring_layout(NG)  #setting the positions with respect to G, not k.

plt.figure()
nx.draw_networkx(k, pos=pos)

othersubgraph = NG.subgraph(range(6, NG.order()))
nx.draw_networkx(othersubgraph, pos=pos, node_color='pink')

plt.show()
